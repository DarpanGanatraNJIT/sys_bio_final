# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

from matplotlib.colors import ListedColormap

# %%
import scipy.stats as stats

# %%
df = pd.read_csv("train_data_2.csv", index_col = 0)

# %%
df = pd.read_csv("train_data_2.csv", index_col = 0)

df.iloc[:, :-1] = df.iloc[:, :-1] + np.random.normal(0, 0.01, size = (5000,10))
time_scale = np.linspace(0, 100, 5000)
plt.figure(figsize = (21, 10))
plt.plot(time_scale, df.S1, label = 'Substrate 1 [S1]')
plt.plot(time_scale, df.C1, label = 'Complex 1 [C1]')
plt.plot(time_scale, df.E1, label = 'Enzyme 1 [E1]')
plt.plot(time_scale, df.P1, label = 'Product 1 [P1]')
plt.plot(time_scale, df.C2, label = 'Complex 2 [C2]')
plt.plot(time_scale, df.E2, label = 'Enzyme 2 [E2]')
plt.plot(time_scale, df.S2, label = 'Substrate 2 [C2]')
plt.plot(time_scale, df.C3, label = 'Complex 3 [C3]')
plt.plot(time_scale, df.P2, label = 'Product 2 [P2]')
plt.plot(time_scale, df.C4, label = 'Complex 4 [C4]')
plt.plot(time_scale, df.E3, label = 'Enzyme 3 [E3]')
plt.title("Two-Cycle CMC With Added Noise")
plt.legend()
plt.show()

# %%
mu = 0
sigma = 0.01
x = np.random.normal(mu, sigma, 100)
plt.figure(figsize = (14, 7))
count, bins, ignored = plt.hist(x, 30, density = True)
plt.plot(bins, 1/(sigma*np.sqrt(2*np.pi))*np.exp(-(bins - mu)**2 / (2* sigma**2)), linewidth = 2, color = 'r')
plt.title(f"Normal distribution $\mu$ = {mu}, $\sigma$ = {sigma}")
plt.show()

# %%
X_train = df[df.columns[df.columns != 'P2']].values
y_train = df['P2'].values

X_train = torch.from_numpy(X_train)
y_train = torch.from_numpy(y_train).view([X_train.shape[0], 1])

X_test = df[df.columns[df.columns != 'P2']].values
y_test = df['P2'].values

X_test = torch.from_numpy(X_test)
y_test = torch.from_numpy(y_test).view([X_test.shape[0], 1])

# %%
X_train.shape
# Out:
# torch.Size([5000, 10])

# %%
num_epochs = 500
learning_rate = 0.01

input_size = 10
hidden_size = 2
num_layers = 1
num_classes = 1

class LSTM(nn.Module):
    def __init__(self, num_classes, input_size, hidden_size, num_layers):
        super(LSTM, self).__init__()
        self.lstm1 = nn.LSTMCell(1,51)
        self.lstm2 = nn.LSTMCell(51,51)
        self.linear = nn.Linear(51,1)
        
    def forward(self, inp, future = 0):
        outputs = list()
        h_t  = torch.zeros(inp.size(0), 51, dtype = torch.double)
        c_t  = torch.zeros(inp.size(0), 51, dtype = torch.double)
        h_t2 = torch.zeros(inp.size(0), 51, dtype = torch.double)
        c_t2 = torch.zeros(inp.size(0), 51, dtype = torch.double)
        for inp_t in inp.split(1, dim = 1):
            h_t, c_t = self.lstm1(inp_t, (h_t, c_t))
            h_t2, c_t2 = self.lstm2(h_t, (h_t2, c_t2))
            output = self.linear(h_t2)
            outputs += [output]
        
        for i in range(future):
            h_t, c_t = self.lstm1(output, (h_t, c_t))
            h_t2, c_t2 = self.lstm2(h_t, (h_t2, c_t2))
            output = self.linear(h_t2)
            outputs += [output]
        outputs = torch.cat(outputs, dim = 1)
        return outputs

lstm = LSTM(num_classes, input_size, hidden_size, num_layers)
lstm.double()
criterion = torch.nn.MSELoss()    # mean-squared error for regression
optimizer = torch.optim.Adam(lstm.parameters(), lr=learning_rate)

# Train the model
for epoch in range(num_epochs):
    outputs = lstm(X_train)
    optimizer.zero_grad()
    loss = criterion(outputs, y_train)
    loss.backward()
    optimizer.step()
    if epoch % 100 == 0:
        print("Epoch: %d, loss: %1.5f" % (epoch, loss.item()))
# Out:
# C:\Users\ganat\Anaconda3\envs\pyt\lib\site-packages\torch\nn\modules\loss.py:529: UserWarning: Using a target size (torch.Size([5000, 1])) that is different to the input size (torch.Size([5000, 10])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# Epoch: 0, loss: 0.61297
# Epoch: 100, loss: 0.16266
# Epoch: 200, loss: 0.13353
# Epoch: 300, loss: 0.07269
# Epoch: 400, loss: 0.05645

# %%
y_pred = lstm(X_test)

pred_df = pd.DataFrame({'time': time_scale, 'predictions': y_pred.detach().numpy()[:, -1]})

plt.figure(figsize = (21, 10))
plt.title("Prediction of Product 2")
plt.plot(pred_df.time, pred_df.predictions, label = 'Prediction')
plt.plot(pred_df.time, y_test, label = 'Ground Truth')
plt.xlim(left = 0, right = 100)
plt.legend()
plt.show()
